# %% [markdown]
# # NGSolve tutorial — start here
#
# This is the **in-notebook twin** of the tutorial's landing page: a map of every unit you
# can navigate from right here. **Run the cell below** to unfold the full map — the story, the
# three parts with their comics, and every unit — with links that open the matching copy for
# wherever you are (*Google Colab*, *JupyterLite*, or a *local Jupyter*). The full rendered
# website (with executed 3D views) lives at
# <https://ngsuite.pages.gwdg.de/ngsum2026-tutorial/>.

# %% [markdown]
# ## The expedition map
#
# *Each card opens that unit in Google Colab.*
#
#
# ### 0 · Setting out — install & run
#
#
# Brand new? **Unit 0** is your on-ramp — installation, the different ways to use these notebooks, and the classic ways to run NGSolve.
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-00.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[0 · Setting out](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/00-setup.ipynb)** — **Start here.** Install NGSolve and explore ways to digest these notebooks.
#
# <div style="clear:both"></div>
#
#
# ### I · Taming the Beast — basics, geometries & first PDEs
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/parts/beast-wild.jpg" alt="" style="width:100%;max-width:360px;border-radius:10px;display:block;margin:8px 0">
#
#
# Earn the Beast’s trust by mastering the **core craft** — a first PDE, geometry & mesh, functions on the mesh, the finite element spaces, solving with Dirichlet data, and the solver toolbox — until it lets you climb on.
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-01.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[1 · Meet the Beast](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/01-meet-the-beast.ipynb)** — The whole NGSolve loop — geometry & mesh, a variational solve, visualization — on your companion creature.
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-02.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[2 · Creating Geometry and Meshes](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/02-geometry.ipynb)** — Forge a sword and a shield, tame the mesh.
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-03.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[3 · What is a CoefficientFunction?](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/03-coefficientfunctions.ipynb)** — local/world coordinates, regions, ... and a creative way to implement FEM
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-04.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[4 · A zoo of finite element spaces](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/04-fespaces.ipynb)** — Explore some of `NGSolve` finite element spaces.
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-05.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[5 · First linear solve](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/05-solving.ipynb)** — Solving linear variational problems and how to treat Dirichlet data.
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-06.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[6 · The solver toolbox 🛠](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/06-linear-solvers.ipynb)** — Direct vs iterative solvers, a short glimpse on solvers.
#
# <div style="clear:both"></div>
#
#
# ### II · In the Saddle — features for applications
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/parts/insaddle.jpg" alt="" style="width:100%;max-width:360px;border-radius:10px;display:block;margin:8px 0">
#
#
# The second tutorial broadens the toolkit: a **mixed** (saddle-point) problem, then the three pillars of real simulations — **time stepping**, **DG / HDG**, and **nonlinear** solves.
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-07.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[7 · Mixed problems — the saddle point 🐎](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/07-saddle-point.ipynb)** — Product FESpaces, block systems, scalar constraints
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-08.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[8 · Unsteady problems — the double-glazing flow](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/08-unsteady-doubleglazing.ipynb)** — Time marching with implicit discretizations.
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-09.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[9 · Discontinuous Galerkin & HDG](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/09-dg-hdg.ipynb)** — Non-conforming methods & upwind stabilization.
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-10.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[10 · Nonlinear problems — Allen–Cahn & Newton](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/10-nonlinear-allencahn.ipynb)** — Newton's method on a phase-separation flow.
#
# <div style="clear:both"></div>
#
#
# ### III · Taking Flight — advanced techniques, and the Grand Expedition
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/parts/riding.jpg" alt="" style="width:100%;max-width:360px;border-radius:10px;display:block;margin:8px 0">
#
#
# The third tutorial **takes flight** — genuinely advanced applications, each fusing the building blocks of Parts I & II, closing with the **Grand Expedition** outlook.
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-11.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[11 · A different pattern: encounter with a relative 🧬](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/11-turing-patterns.ipynb)** — Turing patterns on the curved surface of the beast.
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-12.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[12 · A crowd heads for coffee 🚶☕](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/12-pedestrian-dynamics.ipynb)** — Pedestrian flow model: the crowd, the coffee and the jam.
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-13.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[13 · A puffing thermal plume 🔥🌀](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/13-thermal-plume-hdg.ipynb)** — A buoyant plume: IMEX with Hdiv/HDG
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-14.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[14 · Melting the chocolate 🍫☕](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/14-melting-chocolate.ipynb)** — A phase-field Stefan problem: melting chocolate.
#
# <div style="clear:both"></div>
#
# <img src="https://raw.githubusercontent.com/schruste/ngsum2026-colab/colab/data/thumbs/thumb-15.webp" alt="" style="float:left;width:72px;height:auto;margin:4px 16px 8px 0;border-radius:6px">
#
# **[15 · Deforming domains (ngsxfem) 🫧](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/15-outlook-unfitted.ipynb)** — A two-phase rising bubble on an unfitted mesh (`ngsxfem`).
#
# <div style="clear:both"></div>
