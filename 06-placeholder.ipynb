# %% [markdown]
# # 6 · An uncharted trail 🗺
#
# :::{dropdown} ▶ How to run / view this notebook
# :class: howto-run
#
# | 💻 Local | 🌐 Static | ▶ JupyterLite | ☁️ Colab |
# |:--:|:--:|:--:|:--:|
# | ✅ | [✅](/) | [✅](/lite/notebooks/index.html?path=06-placeholder.ipynb) | [✅](https://colab.research.google.com/github/schruste/ngsum2026-colab/blob/colab/06-placeholder.ipynb) |
#
# <sub>✅ runs here · ⌛ runs but slowly (rough time)</sub>
# :::
#
# :::{note}
# This trail is still being charted. The masters have left the slot open for a future
# skill on the way to taming the Beast — come back soon.
# :::
